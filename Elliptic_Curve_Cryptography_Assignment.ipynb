# %% [markdown]
# <a href="https://colab.research.google.com/github/TiffanyClark225/DES/blob/master/Elliptic_Curve_Cryptography_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = 0
b = 7
p = 127
G = np.array([  96, 51])
n = 127

# %%
# Enumerate all finite field points on the elliptic curve.
# Just check all possible pairs
# Put all the points in a nx2 numpy array called "coord"

# Your code goes here

print("Number of points in EC is ",len(coord)+1)
# Out:
# Number of points in EC is  127

# %%
# Plot them out
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
plt.scatter(coord[:,0], coord[:,1], s=1)
plt.show()

# %%
# Output the addition of two EC points A and B
# From time to time, we will encounter the neutral element which is at infinity
# The convention that I used is to put a negative number in the x-coordinate.
def ECadd(A,B):
  # Adding a neutral element will give back itself
  if A[0]<0 :
    return B
  if B[0]<0 :
    return A
  # This is the main routine to compute ECadd - Your code

# %%
# Test ECadd by ploting the trajectory of k*G
# You can also see how chaotic k*G is.
pt = np.empty([p,2])
pt[0,:] = G
for i in range(n-1):
  pt[i+1,:] = ECadd(pt[i,:],G)
plt.plot(pt[:,0], pt[:,1],'o-',markersize=2)
plt.show()
# Out:
# Output Neural Element

# %%
# Output scalar multiple k*C
def ECmult(k,C):
  # Your code

# %%
import random

# Return a 2x2 numpy matrix
# The first row is the public key
# The second row is the signature of m
# You should build a "semantically secure" signing scheme - that means even for the same private key and message,
# the signature should be different every time you run it.
def ECDSA_sign(m,k):
  # Your code

# %%
m   = 16
sig = ECDSA_sign(m,7)
print(sig)
# Out:
# [[ 80 109]
#  [124  50]]

# %%
def ECDSA_verify(m,sig):
  # Your code

# %%
ECDSA_verify(m,sig)
# Out:
# Signature verified ok
